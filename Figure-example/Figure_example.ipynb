# %% [markdown]
# ## Eduardo Maldonado Cruz, Graduate Research Assistant, The University of Texas at Austin
#
# #### [Twitter](https://twitter.com/emaldonadocruz) | [GitHub](https://github.com/emaldonadocruz) | [LinkedIn](https://www.linkedin.com/in/eduardo-maldonado-8386a898/)

# %% [markdown]
# ## Basic plot example

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.random.uniform(0, 10, 30)
x.sort()
yt = 2 * x + 1
y = yt + np.random.normal(loc=0, scale=2, size=yt.size)

plt.plot(x, yt, label="model")
plt.plot(x, y, "o")
plt.xlabel("x values (unit)")
plt.ylabel("y values (unit)")
plt.title("A plot")
# Out:
# Text(0.5, 1.0, 'A plot')

# %% [markdown]
# Con la siguiente linea de código pueden cargar el estilo de la figura.

# %% [markdown]
# ## Plot example using mplstyle

# %%
plt.style.use('https://raw.githubusercontent.com/emaldonadocruz/Publication_figure_style/master/Publication_figure_style.mplstyle')

# %%
fig, ax = plt.subplots()
ax.plot(x, yt, label="Modelo",color='r')
ax.scatter(x, y,marker='o',color='k',label = 'Puntos medidos')
ax.set_xlabel('x values ($m^3$)')
ax.set_ylabel("y values ($\\frac{m^{3}}{kg}$)")
ax.set_title("Figure example")
ax.legend()
ax.legend(loc='lower right', shadow=True) # locdefine las posiciones

plt.savefig('Figure_example.png',dpi=300)
